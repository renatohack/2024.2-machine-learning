# %%
# !pip install --upgrade gensim
# !pip install tqdm
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.11/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /opt/conda/lib/python3.11/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from gensim) (1.13.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.11/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (4.66.2)

# %%
import pickle
import gensim.corpora as corpora
from gensim.models import CoherenceModel
from gensim.models.ldamulticore import LdaMulticore
from tqdm import tqdm

# %%
with open('pickle/df_proc.p', 'rb') as file:
    df = pickle.load(file)
df.head()
# Out:
#                                                 text
# 0  programa treinamento jornalismo agroindústria ...
# 1  ofício enviado juiz sergio moro feira presiden...
# 2  ex governador rio sérgio cabral transferido co...
# 3  aplausos vaias juiz federal sergio moro respon...
# 4  ex executivo empreiteira odebrecht afirmou aco...

# %%
tokenized_docs = [doc.lower().split() for doc in df['text']]

# %%
id2word = corpora.Dictionary(tokenized_docs)
corpus = [id2word.doc2bow(text) for text in tokenized_docs]

# %%
def compute_coherence_values(corpus, dictionary, texts, range_lda): # meu
    coherence_values = []
    model_list = []
    for num_topics in tqdm(range_lda):
        model = LdaMulticore(corpus=corpus, num_topics=num_topics, id2word=dictionary, random_state=42)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

# %%
limit=151; start=2; step=1;
range_lda = range(start, limit, step)
model_list, coherence_values = compute_coherence_values(corpus=corpus, dictionary=id2word, texts=tokenized_docs, range_lda=range_lda)
# Out:
#   0%|          | 0/148 [00:05<?, ?it/s]Process AccumulatingWorker-14:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process AccumulatingWorker-19:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# Process AccumulatingWorker-12:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# Process AccumulatingWorker-22:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 limit=150; start=2; step=1;
#       2 range_lda = range(start, limit, step)
# ----> 3 model_list, coherence_values = compute_coherence_values(corpus=corpus, dictionary=id2word, texts=tokenized_docs, range_lda=range_lda)
#
# Cell In[19], line 8, in compute_coherence_values(corpus, dictionary, texts, range_lda)
#       6     model_list.append(model)
#       7     coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
# ----> 8     coherence_values.append(coherencemodel.get_coherence())
#       9 return model_list, coherence_values
#
# File /opt/conda/lib/python3.11/site-packages/gensim/models/coherencemodel.py:614, in CoherenceModel.get_coherence(self)
#     605 def get_coherence(self):
#     606     """Get coherence value based on pipeline parameters.
#     607
#     608     Returns
#    (...)
#     612
#     613     """
# --> 614     confirmed_measures = self.get_coherence_per_topic()
#     615     return self.aggregate_measures(confirmed_measures)
#
# File /opt/conda/lib/python3.11/site-packages/gensim/models/coherencemodel.py:574, in CoherenceModel.get_coherence_per_topic(self, segmented_topics, with_std, with_support)
#     572     segmented_topics = measure.seg(self.topics)
#     573 if self._accumulator is None:
# --> 574     self.estimate_probabilities(segmented_topics)
#     576 kwargs = dict(with_std=with_std, with_support=with_support)
#     577 if self.coherence in BOOLEAN_DOCUMENT_BASED or self.coherence == 'c_w2v':
#
# File /opt/conda/lib/python3.11/site-packages/gensim/models/coherencemodel.py:546, in CoherenceModel.estimate_probabilities(self, segmented_topics)
#     543     if self.coherence == 'c_w2v':
#     544         kwargs['model'] = self.keyed_vectors
# --> 546     self._accumulator = self.measure.prob(**kwargs)
#     548 return self._accumulator
#
# File /opt/conda/lib/python3.11/site-packages/gensim/topic_coherence/probability_estimation.py:156, in p_boolean_sliding_window(texts, segmented_topics, dictionary, window_size, processes)
#     154     accumulator = ParallelWordOccurrenceAccumulator(processes, top_ids, dictionary)
#     155 logger.info("using %s to estimate probabilities from sliding windows", accumulator)
# --> 156 return accumulator.accumulate(texts, window_size)
#
# File /opt/conda/lib/python3.11/site-packages/gensim/topic_coherence/text_analysis.py:445, in ParallelWordOccurrenceAccumulator.accumulate(self, texts, window_size)
#     442     logger.warn("stats accumulation interrupted; <= %d documents processed", self._num_docs)
#     443     interrupted = True
# --> 445 accumulators = self.terminate_workers(input_q, output_q, workers, interrupted)
#     446 return self.merge_accumulators(accumulators)
#
# File /opt/conda/lib/python3.11/site-packages/gensim/topic_coherence/text_analysis.py:522, in ParallelWordOccurrenceAccumulator.terminate_workers(self, input_q, output_q, workers, interrupted)
#     520 accumulators = []
#     521 while len(accumulators) != len(workers):
# --> 522     accumulators.append(output_q.get())
#     523 logger.info("%d accumulators retrieved from output queue", len(accumulators))
#     525 for worker in workers:
#
# File /opt/conda/lib/python3.11/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /opt/conda/lib/python3.11/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /opt/conda/lib/python3.11/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File /opt/conda/lib/python3.11/multiprocessing/connection.py:395, in Connection._recv(self, size, read)
#     393 remaining = size
#     394 while remaining > 0:
# --> 395     chunk = read(handle, remaining)
#     396     n = len(chunk)
#     397     if n == 0:
#
# KeyboardInterrupt:
# Process AccumulatingWorker-16:
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# Process AccumulatingWorker-15:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# Process AccumulatingWorker-21:
# Process AccumulatingWorker-18:
# Process AccumulatingWorker-20:
# Process AccumulatingWorker-17:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
# Process AccumulatingWorker-13:
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 207, in _finalize_close
#     with notempty:
#   File "/opt/conda/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/threading.py", line 272, in __enter__
#     return self._lock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/opt/conda/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
with open('model_list.p', 'wb') as file:
    pickle.dump(model_list, file)

with open('coherence_values.p', 'wb') as file:
    pickle.dump(coherence_values, file)
