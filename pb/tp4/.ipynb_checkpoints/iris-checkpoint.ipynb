# %% [markdown]
# # Init

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /opt/conda/lib/python3.11/site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (3.8.4)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.13.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.4.2)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
import utils
import pandas as pd
import math
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.preprocessing import label_binarize
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()
x, y = iris.data, iris.target
labels = iris.target_names

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Clusterização K-Médias

# %%
silhouette_scores, range_k = utils.visualize_silhouette(x_train, 5)
# Out:
# N Clusters: 2 Avg: 0.5695459932303369
# N Clusters: 3 Avg: 0.4694836508606194
# N Clusters: 4 Avg: 0.4058685215290406
# N Clusters: 5 Avg: 0.352053647204979

# %%
utils.visualize_sil_score_per_cluster(silhouette_scores, range_k)

# %%
utils.visualize_elbow(x_train, 10)

# %% [markdown]
# # Criação de Features

# %%
n = 3

# %%
km = KMeans(n_clusters=n, random_state=0)
clusters = km.fit_predict(x_train)
centroids = km.cluster_centers_

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_train[:, 0], y=x_train[:, 1], hue=clusters, palette='viridis', s=100)
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s=300, c='red', marker='X')
plt.title(f"Clusterização K-Médias (K={n})")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
x_train_mod, x_test_mod = utils.criar_features_dataset(x_train, x_test, centroids)

# %%
x_train_mod
# Out:
#             0         1         2         3        F0        F1        F2
# 0    0.613030  0.108501  0.947518  0.736072  1.496175  3.519533  0.549536
# 1   -0.567766 -0.124001  0.384914  0.347530  0.947263  2.580260  1.897734
# 2   -0.803926  1.038510 -1.302896 -1.336154  3.081229  0.315483  3.871303
# 3    0.258791 -0.124001  0.609956  0.736072  1.056831  3.212440  0.987127
# 4    0.613030 -0.589006  1.003778  1.254129  1.458149  4.058841  0.927448
# ..        ...       ...       ...       ...       ...       ...       ...
# 115 -1.158164  0.108501 -1.302896 -1.465668  2.782224  0.740909  4.039730
# 116  0.494950 -0.356503  1.003778  0.736072  1.185539  3.625694  0.836117
# 117 -0.095448 -0.821508  0.159873 -0.300041  0.572944  2.585561  2.176386
# 118  2.148065  1.736017  1.622642  1.254129  3.861239  5.097772  2.018454
# 119 -1.512403  0.341003 -1.359156 -1.336154  2.986368  0.687301  4.207050
#
# [120 rows x 7 columns]

# %%
x_test_mod
# Out:
#            0         1         2         3        F0        F1        F2
# 0  -0.095448 -0.589006  0.722476  1.513157  1.381114  3.849514  1.513913
# 1   0.140712 -1.984019  0.103613 -0.300041  1.221570  3.487273  2.824272
# 2  -0.449687  2.666026 -1.359156 -1.336154  4.286603  1.939614  4.417873
# 3   1.675747 -0.356503  1.397601  0.736072  2.211969  4.482951  0.934775
# 4  -1.040085  0.806008 -1.302896 -1.336154  3.003460  0.062559  3.947799
# 5   0.494950  0.573506  1.228820  1.642671  2.329969  4.173572  0.995717
# 6  -1.040085  1.038510 -1.415416 -1.206640  3.141540  0.256906  3.983849
# 7   0.967269  0.108501  0.497435  0.347530  1.504476  3.225825  0.820602
# 8   1.085349 -0.589006  0.553695  0.218015  1.253832  3.486930  1.167634
# 9   0.258791 -0.589006  0.103613  0.088501  0.558760  2.740100  1.688005
# 10  0.258791 -1.054010  1.003778  0.218015  0.785211  3.575020  1.672792
# 11  0.613030  0.341003  0.384914  0.347530  1.465113  2.907922  1.015216
# 12  0.258791 -0.589006  0.497435 -0.041013  0.598326  2.906825  1.605041
# 13  0.731110 -0.589006  0.441175  0.347530  0.911415  3.284976  1.187547
# 14  0.258791 -0.356503  0.497435  0.218015  0.703103  2.926218  1.343183
# 15 -1.158164  1.271012 -1.359156 -1.465668  3.421000  0.515295  4.218368
# 16  0.140712 -0.356503  0.384914  0.347530  0.637940  2.878177  1.394978
# 17 -0.449687 -1.054010  0.328654 -0.041013  0.467904  2.842191  2.315268
# 18 -1.276244 -0.124001 -1.359156 -1.206640  2.634955  0.975127  3.998892
# 19 -0.567766  1.968519 -1.415416 -1.077126  3.657538  1.260575  4.001770
# 20 -0.331607 -0.589006  0.609956  0.995100  0.912833  3.370908  1.648290
# 21 -0.331607 -0.124001  0.384914  0.347530  0.854396  2.631569  1.695575
# 22 -1.276244  0.806008 -1.077854 -1.336154  2.974192  0.362640  3.959016
# 23 -1.748563 -0.356503 -1.359156 -1.336154  2.889637  1.380652  4.384822
# 24  0.376871 -0.589006  0.553695  0.736072  0.803971  3.392185  1.150071
# 25 -1.512403  1.271012 -1.584197 -1.336154  3.600009  0.726306  4.470738
# 26 -0.922005  1.736017 -1.077854 -1.077126  3.389441  0.982810  3.877188
# 27  0.376871 -0.356503  0.272394  0.088501  0.763112  2.781418  1.451245
# 28 -1.040085 -1.751517 -0.290210 -0.300041  1.488450  2.933961  3.391184
# 29 -1.040085  0.806008 -1.246635 -1.077126  2.844740  0.221547  3.766547

# %% [markdown]
# # SVM

# %% [markdown]
# ## Modelo de ML

# %%
svc_ori = SVC(probability=True)

# %%
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'degree': [2, 3, 4],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# %% [markdown]
# ### Dataset Original

# %%
grid_ori = GridSearchCV(estimator=svc_ori, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_ori.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %% [markdown]
# ### Dataset Modificado

# %%
svc_mod = SVC(probability=True)

# %%
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'degree': [2, 3, 4],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# %%
grid_mod = GridSearchCV(estimator=svc_mod, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_mod.fit(x_train_mod, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %% [markdown]
# ## Avaliação dos Modelos

# %% [markdown]
# ### Dataset Original

# %%
y_pred = utils.show_estimator_results(grid_ori, x_test, y_test)
# Out:
# Melhores parâmetros GridSearch: {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Score GridSearch: 1.0
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Dataset Modificado

# %%
y_pred = utils.show_estimator_results(grid_mod, x_test_mod, y_test)
# Out:
# Melhores parâmetros GridSearch: {'C': 0.1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Score GridSearch: 1.0
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Modelo de ML

# %%
rf_ori = RandomForestClassifier()

# %%
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2'],
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# %% [markdown]
# ### Dataset Original

# %%
grid_ori = GridSearchCV(estimator=rf_ori, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_ori.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]},
#              scoring='accuracy')

# %% [markdown]
# ### Dataset Modificado

# %%
rf_mod = RandomForestClassifier()

# %%
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2'],
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}

# %%
grid_mod = GridSearchCV(estimator=rf_mod, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_mod.fit(x_train_mod, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100]},
#              scoring='accuracy')

# %% [markdown]
# ## Avaliação dos Modelos

# %% [markdown]
# ### Dataset Original

# %%
y_pred = utils.show_estimator_results(grid_ori, x_test, y_test)
# Out:
# Melhores parâmetros GridSearch: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# Score GridSearch: 0.9666666666666667
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.93      1.00      0.96        13
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Dataset Modificado

# %%
y_pred = utils.show_estimator_results(grid_mod, x_test_mod, y_test)
# Out:
# Melhores parâmetros GridSearch: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 10}
# Score GridSearch: 1.0
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(3):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()
