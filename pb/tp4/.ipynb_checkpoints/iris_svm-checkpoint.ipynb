# %% [markdown]
# ### Init

# %%
# !pip install yellowbrick

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
import utils
import pandas as pd
import math
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
import seaborn as sns

# %%
iris = load_iris()
x, y = iris.data, iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Clusterização K-Médias

# %%
utils.visualize_silhouette(x_train, 5)
# Out:
# N Clusters: 2 Avg: 0.6757500985509393
# N Clusters: 3 Avg: 0.5572550286954637
# N Clusters: 4 Avg: 0.4965676156117855
# N Clusters: 5 Avg: 0.5018354525389606

# %%
utils.visualize_elbow(x_train)

# %% [markdown]
# ### Criação de Features

# %%
x_train_mod, x_test_mod = utils.criar_features_dataset(x_train, x_test, 3)

# %%
x_train_mod.columns = x_train_mod.columns.astype(str)
x_train_mod
# Out:
#        0    1    2    3        F0        F1        F2
# 0    6.4  3.1  5.5  1.8  0.580788  4.553471  1.387964
# 1    5.4  3.0  4.5  1.5  1.984827  3.335166  0.537277
# 2    5.2  3.5  1.5  0.2  4.905279  0.211830  3.261254
# 3    6.1  3.0  4.9  1.8  1.146775  3.947248  0.769560
# 4    6.4  2.8  5.6  2.2  0.581744  4.819804  1.578396
# ..   ...  ...  ...  ...       ...       ...       ...
# 115  4.9  3.1  1.5  0.1  5.037149  0.356982  3.300808
# 116  6.3  2.9  5.6  1.8  0.670475  4.631082  1.396583
# 117  5.8  2.7  4.1  1.0  2.234473  2.939170  0.493739
# 118  7.7  3.8  6.7  2.2  1.486825  6.214231  3.282445
# 119  4.6  3.2  1.4  0.2  5.208389  0.472582  3.457520
#
# [120 rows x 7 columns]

# %%
x_test_mod.columns = x_test_mod.columns.astype(str)
x_test_mod
# Out:
#       0    1    2    3        F0        F1        F2
# 0   5.8  2.8  5.1  2.4  1.307493  4.343991  1.233063
# 1   6.0  2.2  4.0  1.0  2.359987  3.070079  0.777889
# 2   5.5  4.2  1.4  0.2  5.005950  0.933425  3.536665
# 3   7.3  2.9  6.3  1.8  0.807316  5.593724  2.475480
# 4   5.0  3.4  1.5  0.2  4.969975  0.059914  3.283562
# 5   6.3  3.3  6.0  2.5  0.812119  5.229551  2.104493
# 6   5.0  3.5  1.3  0.3  5.111489  0.198714  3.445899
# 7   6.7  3.1  4.7  1.5  1.158343  3.871030  1.013794
# 8   6.8  2.8  4.8  1.4  1.154981  4.002275  1.071966
# 9   6.1  2.8  4.0  1.3  2.036496  3.015558  0.468330
# 10  6.1  2.6  5.6  1.4  1.138997  4.503275  1.281839
# 11  6.4  3.2  4.5  1.5  1.410116  3.572294  0.762889
# 12  6.1  2.8  4.7  1.2  1.558341  3.596615  0.499110
# 13  6.5  2.8  4.6  1.5  1.321020  3.739910  0.723418
# 14  6.1  2.9  4.7  1.4  1.440132  3.639879  0.475161
# 15  4.9  3.6  1.4  0.1  5.146151  0.277812  3.479048
# 16  6.0  2.9  4.5  1.5  1.598118  3.468318  0.297396
# ...

# %% [markdown]
# ### Modelo de ML

# %% [markdown]
# #### Dataset Original

# %%
svc_ori = SVC()

# %%
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'degree': [2, 3, 4],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# %%
grid_ori = GridSearchCV(estimator=svc_ori, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_ori.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %%
print(f"Melhores parâmetros KNN: {grid_ori.best_params_}")
# Out:
# Melhores parâmetros KNN: {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}

# %%
grid_ori.score(x_test, y_test)
# Out:
# 1.0

# %%
y_pred = grid_ori.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
cm = confusion_matrix(y_test, y_pred)

# Define the labels
labels = ['No Stroke', 'Stroke']

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #### Dataset Modificado

# %%
svc_mod = SVC()

# %%
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'degree': [2, 3, 4],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# %%
grid_mod = GridSearchCV(estimator=svc_mod, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_mod.fit(x_train_mod, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %%
print(f"Melhores parâmetros KNN: {grid_mod.best_params_}")
# Out:
# Melhores parâmetros KNN: {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %%
grid_mod.score(x_test_mod, y_test)
# Out:
# 1.0

# %%
y_pred = grid_mod.predict(x_test_mod)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
cm = confusion_matrix(y_test, y_pred)

# Define the labels
labels = ['No Stroke', 'Stroke']

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### Avaliação de Modelos

# %% [markdown]
# ### Análise Comparativa
