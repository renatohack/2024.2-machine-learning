# %% [markdown]
# # Init

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /opt/conda/lib/python3.11/site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (3.8.4)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.13.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.4.2)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.4.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
import utils
import pandas as pd
import math
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.preprocessing import label_binarize
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
wine = load_wine()
x, y = wine.data, wine.target
labels = wine.target_names

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Clusterização K-Médias

# %%
silhouette_scores, range_k = utils.visualize_silhouette(x_train, 5)
# Out:
# N Clusters: 2 Avg: 0.2616600530532147
# N Clusters: 3 Avg: 0.288819165011418
# N Clusters: 4 Avg: 0.23832352878271698
# N Clusters: 5 Avg: 0.21092682821678096

# %%
utils.visualize_sil_score_per_cluster(silhouette_scores, range_k)

# %%
utils.visualize_elbow(x_train, 10)

# %% [markdown]
# # Criação de Features

# %%
n = 3

# %%
km = KMeans(n_clusters=n, random_state=0)
clusters = km.fit_predict(x_train)
centroids = km.cluster_centers_

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=x_train[:, 0], y=x_train[:, 1], hue=clusters, palette='viridis', s=100)
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s=300, c='red', marker='X')
plt.title(f"Clusterização K-Médias (K={n})")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
x_train_mod, x_test_mod = utils.criar_features_dataset(x_train, x_test, centroids)

# %%
x_train_mod
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.876683  0.798429  0.644130  0.129743  0.488532 -0.703262 -1.428468
# 1   -0.366591 -0.758130 -0.397799  0.333800 -1.413024 -1.441531 -0.502998
# 2   -1.696894 -0.344248 -0.323375 -0.453279 -0.145320  1.249050  0.319642
# 3    0.516134  1.383263  0.420859  1.004275  0.136392 -0.752480 -1.233091
# 4    0.640461 -0.506202  0.904612  0.129743 -0.286176  0.445157  0.679547
# ..        ...       ...       ...       ...       ...       ...       ...
# 137 -1.448239 -0.587179 -1.811844 -0.016013 -0.990456  0.395939 -0.317904
# 138 -0.764438 -1.082039 -1.662997  0.013139 -1.553880 -0.243895  0.052284
# 139 -0.702275 -0.686151 -0.658281  0.858519  0.558960 -0.424360  0.144831
# 140  1.137771 -0.623169 -0.918763 -1.036300  0.065964  1.380298  1.481621
# 141  1.461022  0.123620  0.420859  0.129743 -0.638316 -0.949352 -1.284506
#
#             7         8         9        10        11        12        F0  \
# 0    1.072457 -1.368203  0.351932  0.029017 -1.064122 -0.205908  1.854356
# 1    1.701100  0.023668 -0.841146  0.029017 -0.730832 -0.817047  3.505400
# 2   -1.520697 -0.434631 -0.756829  0.901974  0.519005 -1.312565  5.407977
# 3    0.522394 -0.332787  0.950579 -1.105828 -1.425187  0.025334  1.064582
# 4   -0.656312  0.091564 -0.643002  0.727382  1.713295  0.339162  5.081347
# ..        ...       ...       ...       ...       ...       ...       ...
# 137  0.050911 -0.315813 -1.258512 -0.058279 -0.203123 -1.081323  4.539285
# 138 -0.734893 -0.960826 -0.153967  0.727382  1.241134 -0.767495  5.088710
# 139 -0.184830  0.006694 -1.258512  0.465495  0.519005 -1.312565  4.369436
# 140 -1.206375  0.906318  0.444680 -0.189223  1.032828  0.801646  5.780736
# 141  0.600974 -0.621345  1.962377 -1.455010 -1.216880 -0.271977  2.014609
#
#            F1        F2
# 0    4.109742  4.832095
# 1    2.823104  5.292735
# 2    2.426673  4.109219
# 3    4.417895  5.091051
# 4    3.013515  2.070749
# ..        ...       ...
# 137  1.891732  4.922737
# 138  2.484752  4.523784
# 139  1.474882  4.129827
# 140  4.237402  1.900252
# 141  5.004879  5.292134
#
# [142 rows x 16 columns]

# %%
x_test_mod
# Out:
#            0         1         2         3         4         5         6  \
# 0   0
# 4   4.288633  5.164541
# 5   6.396597  6.241157
# 6   4.630979  2.083928
# 7   4.354546  5.783055
# 8   1.583156  4.296721
# 9   2.167347  4.992199
# 10  3.802602  5.002836
# 11  5.707889  7.130238
# 12  5.318495  1.978712
# 13  3.338506  3.370471
# 14  4.638637  4.992336
# 15  2.306129  4.755480
# 16  5.022507  3.088229
# 17  6.173154  2.965140
# 18  3.459220  5.262894
# 19  4.374860  1.761634
# 20  3.963052  4.225638
# 21  2.862450  1.968262
# 22  3.643123  2.694487
# 23  1.745108  3.835015
# 24  3.941884  5.615017
# 25  1.816038  4.217066
# 26  2.499973  4.090507
# 27  1.943030  4.743338
# 28  3.739536  5.169206
# 29  4.789987  5.630238
# 30  3.792443  1.812395
# 31  4.527121  1.652438
# 32  2.935842  5.059873
# 33  4.495912  2.567093
# 34  4.557614  2.214930
# 35  3.187015  1.943370

# %% [markdown]
# # SVM

# %% [markdown]
# ## Modelo de ML

# %%
param_grid = {
    'kernel': ['linear', 'poly', 'rbf'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

# %% [markdown]
# ### Dataset Original

# %%
svc_ori = SVC(probability=True)

# %%
grid_ori = GridSearchCV(estimator=svc_ori, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_ori.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %% [markdown]
# ### Dataset Modificado

# %%
svc_mod = SVC(probability=True)

# %%
grid_mod = GridSearchCV(estimator=svc_mod, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_mod.fit(x_train_mod, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              scoring='accuracy')

# %% [markdown]
# ## Avaliação dos Modelos

# %% [markdown]
# ### Dataset Original

# %%
y_pred = utils.show_estimator_results(grid_ori, x_test, y_test)
# Out:
# Melhores parâmetros GridSearch: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Score GridSearch: 1.0
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(n):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Dataset Modificado

# %%
y_pred = utils.show_estimator_results(grid_mod, x_test_mod, y_test)
# Out:
# Melhores parâmetros GridSearch: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Score GridSearch: 1.0
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         6
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(n):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Modelo de ML

# %%
param_grid = {
    'n_estimators': [10, 50, 100],
    'max_depth': [None, 5, 10],
    'max_features': [None, 'sqrt', 'log2'],
}

# %% [markdown]
# ### Dataset Original

# %%
rf_ori = RandomForestClassifier()

# %%
grid_ori = GridSearchCV(estimator=rf_ori, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_ori.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              scoring='accuracy')

# %% [markdown]
# ### Dataset Modificado

# %%
rf_mod = RandomForestClassifier()

# %%
grid_mod = GridSearchCV(estimator=rf_mod, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
grid_mod.fit(x_train_mod, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              scoring='accuracy')

# %% [markdown]
# ## Avaliação dos Modelos

# %% [markdown]
# ### Dataset Original

# %%
y_pred = utils.show_estimator_results(grid_ori, x_test, y_test)
# Out:
# Melhores parâmetros GridSearch: {'max_depth': None, 'max_features': 'log2', 'n_estimators': 50}
# Score GridSearch: 0.9722222222222222
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.94      0.97        16
#            2       1.00      1.00      1.00         6
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.98      0.98        36
# weighted avg       0.97      0.97      0.97        36

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(n):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Dataset Modificado

# %%
y_pred = utils.show_estimator_results(grid_mod, x_test_mod, y_test)
# Out:
# Melhores parâmetros GridSearch: {'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Score GridSearch: 0.9722222222222222
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        16
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.97        36
#    macro avg       0.95      0.98      0.96        36
# weighted avg       0.98      0.97      0.97        36

# %%
utils.show_cm(y_test, y_pred, labels)

# %%
# Binarize the output
y_train_bin = label_binarize(y_train, classes=[0, 1, 2])
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])

y_score = grid_ori.best_estimator_.predict_proba(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n):  # número de classes
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
for i in range(n):
    plt.plot(fpr[i], tpr[i], label=f'Classe {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC Multiclasse')
plt.legend(loc="lower right")
plt.show()
