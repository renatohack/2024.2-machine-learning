# %%
from sklearn.datasets import load_iris
import pandas as pd

# Carregar o dataset Iris
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

X.head(), y.head()
# Out:
# (   sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
#  0                5.1               3.5                1.4               0.2
#  1                4.9               3.0                1.4               0.2
#  2                4.7               3.2                1.3               0.2
#  3                4.6               3.1                1.5               0.2
#  4                5.0               3.6                1.4               0.2,
#  0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  dtype: int64)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# Dividir o dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

'''# Treinar o modelo
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)'''

dt = DecisionTreeClassifier()
param_grid = {
    'max_depth': range(1, 10, 1),  # Maximum depth of the tree
    'ccp_alpha': np.linspace(0, 0.3, num=10),  # Number of features to consider when looking for the best split
    'min_samples_leaf': range(1, 10, 1),  # Number of features to consider when looking for the best split
    'max_leaf_nodes': [None, 10, 20, 30],  # Number of features to consider when looking for the best split
}

grid_dt = GridSearchCV(dt, param_grid, cv=5)
grid_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'ccp_alpha': array([0.        , 0.03333333, 0.06666667, 0.1       , 0.13333333,
#        0.16666667, 0.2       , 0.23333333, 0.26666667, 0.3       ]),
#                          'max_depth': range(1, 10),
#                          'max_leaf_nodes': [None, 10, 20, 30],
#                          'min_samples_leaf': range(1, 10)})

# %%
from sklearn.metrics import accuracy_score

# Prever no conjunto de teste
y_pred = grid_dt.predict(X_test)

# Calcular a acurácia
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

model = grid_dt.best_estimator_

# Plotar a árvore de decisão
plt.figure(figsize=(20,10))
plot_tree(model, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()

# %%
# Importância das features
importances = model.feature_importances_

# Plotar as importâncias
plt.figure(figsize=(10,5))
plt.bar(iris.feature_names, importances)
plt.xlabel('Features')
plt.ylabel('Importância')
plt.title('Importância das Features')
plt.show()

# %%
import numpy as np

# Selecionar duas features para visualização
X_reduced = X[['sepal length (cm)', 'sepal width (cm)']]
X_train_reduced, X_test_reduced, y_train, y_test = train_test_split(X_reduced, y, test_size=0.3, random_state=42)

# Treinar o modelo com duas features
model_reduced = DecisionTreeClassifier(random_state=42)
model_reduced.fit(X_train_reduced, y_train)

# Gerar uma grade de pontos
x_min, x_max = X_reduced.iloc[:, 0].min() - 1, X_reduced.iloc[:, 0].max() + 1
y_min, y_max = X_reduced.iloc[:, 1].min() - 1, X_reduced.iloc[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

# Prever em cada ponto da grade
Z = model_reduced.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plotar as fronteiras de decisão
plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(X_reduced.iloc[:, 0], X_reduced.iloc[:, 1], c=y, edgecolor='k', s=20)
plt.xlabel('Sepal length (cm)')
plt.ylabel('Sepal width (cm)')
plt.title('Fronteiras de Decisão - Decision Tree')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
